# %% [markdown]
# # Python实验部分（总分：60分）

# %% [markdown]
# ## 实验1：栈Stack的实现（总分：30分）

# %% [markdown]
# **实验要求如下：**
# -- --
# + （1）查询资料，给出“栈Stack”的定义和特性。（5分）
# + （2）通过定义函数或类等，实现如下的功能：（15分）
#     + Stack()：创建一个空栈，不包含任何数据项
#     + isEmpty()：返回栈是否为空栈
#     + push(item)：将item加入栈顶，无返回值
#     + peek()：“窥视”栈顶数据项，返回栈顶的数据项但不移除，栈不被修改
#     + size()：返回栈中有多少个数据项
#     + pop()：将栈顶数据项移除，并返回，栈被修改
#     + size()：返回栈中有多少个数据项
#
# + （3）按照下图所示的顺序，对结果进行验证：（10分）
#
# ![image.png](attachment:177fe294-fa60-4d2a-9d35-f86caddacc7c.png)

# %% [markdown]
# ## 实验2：银行账户类的实现（总分：30分）
# **实验要求如下：**
# -- --
# + 用类和对象创建一个银行账户类，包括账号、用户姓名、密码和余额属性，实现开户、查询余额、取款、存款和转账功能。具体功能要求：（20分）
#
#    + 开户方法 Account()：创建账户的账号、密码、姓名和余额；
#    + 查询方法 Display()：显示账户的账号、姓名和余额信息；
#    + 取款方法 takeMoney()：先让用户输入密码验证，密码正确后输入取款金额，取款成功后余额减除相应的金额；
#    + 存款方法 saveMoney()：存款是直接传入存款金额，账户余额增加相应的金额；
#    + 转账方法 transform()：实现两个账户的转账功能；余额不足，提醒转账识别。
#
# + 以***自己的学号***为账号，以***自己的姓名***为用户姓名实现开户、查询余额、取款、存款的功能；并向账号***20232024***，用户姓名为***Zhang ZM***实现转账功能。（10分）
